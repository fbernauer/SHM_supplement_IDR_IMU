# %%
import math as m
import numpy as np
import scipy as sp

from obspy.core import UTCDateTime, read, Stream, Trace

from attitude_correction import Attitude
from utils import apply_att_corr

import matplotlib.pyplot as plt

import matplotlib.colors as colors
# %matplotlib ipympl
# %matplotlib inline

# %% [markdown]
# The attitude correction algorithm is described in datail in Lin et al. 2010, BSSA,
# https://doi.org/10.1785/0120090123<br>
# Basically the following steps are implemented in the function attitude_correction.Attitude
# 1. From rotation rates $\dot\Theta_i$ , calculate Euler-angle sets $\Psi$ via
# attitude equation ($S_x = sin(\Psi_x)$, $C_x = cos(\Psi_x)$, i denotes an axis in the body fixed coordinate system).
# \begin{equation*}
# \begin{pmatrix}
#     \dot\Psi_x(t) \\
#     \dot\Psi_y(t) \\
#     \dot\Psi_z(t)
# \end{pmatrix}
# =
# \begin{pmatrix}
#     1 & S_x tan(\Psi_y) & C_x tan(\Psi_y)\\
#     0 & C_x & -S_x \\
#     0 & S_x sec(\Psi_y) & C_x sec(\Psi_y)\\
# \end{pmatrix}
# \dot\Theta_i
# \end{equation*}
#
# 2. Correct accelerometer outputs for
# tilt-induced gravitational accelerations via the attitude correction equation, yielding translational velocity
# in the body-attached frame. $f_i$ is the body frame accelerometer output.
# \begin{equation*}
# \ddot u_x = f_x + gS_y
# \end{equation*}
# \begin{equation*}
# \ddot u_y = f_y - gC_yS_x
# \end{equation*}
# \begin{equation*}
# \ddot u_z = f_z + g(1-C_yC_x)
# \end{equation*}
#
# 3. Construct the transformation matrix (a set of three Euler rotations) from
# these Euler-angle sets, and transform these body-attached
# frame velocities (P_B) into the global frame vector (P_G).
# \begin{equation*}
# P_G =
# \begin{pmatrix}
#     C_z & -S_z & 0\\
#     S_z &  C_z & 0\\
#     0   &  0   & 1\\
# \end{pmatrix}
# \begin{pmatrix}
#     C_y  & 0  & S_y\\
#     0    & 1  & 0  \\
#     -S_y & 0  & C_y\\
# \end{pmatrix}
# \begin{pmatrix}
#     1 &  0   &    0\\
#     0 &  C_x & -S_x\\
#     0 &  S_x &  C_x\\
# \end{pmatrix}
# P_B
# \end{equation*}
#
#
# 4. Integrate these geographic-frame velocities to geographic-
# frame displacements.

# %% [markdown]
# To understand the data we need to clarify positions and orientations of the stations and channels. The rotation rate channels are named according the the right-hand rule.
#
# <img src="structure_setup_CAD_sup.png" width=1050 height=1050 />

# %% [markdown]
# We start with defining some miniSeed identifiers

# %%
# path to the data folder
path = './data/'

# define some miniseed identifiers
net = 'XX'         # Network code
loc= ''            # Location code

# displacement transducers station codes
sta_DISP0 = 'DS00'
sta_DISP1 = 'DS01'
sta_DISP2 = 'DS02'

cha_disp = 'DXY'    # Channel code

# PCB accelerometers station codes
sta_ACC0 = 'AC00'
sta_ACC1 = 'AC01'
sta_ACC2 = 'AC02'

cha_acc = 'DNY'    # Channel code

# IMU50 station codes
sta_6C0 = '6C00'
sta_6C1 = '6C01'
sta_6C2 = '6C02'

# we take all 6 channels from the IMU50 data
cha_6C = 'D*'

# %% [markdown]
# Next we define the earth gravitational acceleration in m/s/s

# %%
one_g = 9.81

# %% [markdown]
# In the next cell you can choose the high-pass cut-off frequency applied for double integration

# %%
fmin = 0.5 # 1.0, 2.0
fmax = 50

# %% [markdown]
# Now, we define some event parameters like an event identifier, the start time in UTC and its diraation. We create a dictionary where we can store the maximum IDR and the permenent IDR for later analysis and plotting.

# %%
EV = {'eid':'90', 'ename':'Kobe', 'time':UTCDateTime('2023-09-28T14:53:42'), 'dt':59,
     'max_id_corr_2nd':0, 'max_id_ref_2nd':0, 'max_id_refa_2nd':0, 'max_id_rot_2nd':0,
     'max_id_corr_1st':0, 'max_id_ref_1st':0, 'max_id_refa_1st':0, 'max_id_rot_1st':0,
     'static_def_rot_1st':0, 'static_def_ref_1st':0, 'static_def_rot_2nd':0, 'static_def_ref_2nd':0,}

# %% [markdown]
# Let's read the data.

# %%
evid = EV['eid']
utctime = EV['time']

YYYY = str(utctime.year)
DOY = str(utctime.julday).zfill(3)

st_DISP0 = read(path+net+'.'+sta_DISP0+'.'+loc+'.'+cha_disp+'.D.'+YYYY+'.'+DOY)
st_DISP1 = read(path+net+'.'+sta_DISP1+'.'+loc+'.'+cha_disp+'.D.'+YYYY+'.'+DOY)
st_DISP2 = read(path+net+'.'+sta_DISP2+'.'+loc+'.'+cha_disp+'.D.'+YYYY+'.'+DOY)

st_ACC0 = read(path+net+'.'+sta_ACC0+'.'+loc+'.'+cha_acc+'.D.'+YYYY+'.'+DOY)
st_ACC1 = read(path+net+'.'+sta_ACC1+'.'+loc+'.'+cha_acc+'.D.'+YYYY+'.'+DOY)
st_ACC2 = read(path+net+'.'+sta_ACC2+'.'+loc+'.'+cha_acc+'.D.'+YYYY+'.'+DOY)

st_6C0_raw = read(path+net+'.'+sta_6C0+'.'+loc+'.'+cha_6C+'.D.'+YYYY+'.'+DOY)
st_6C1_raw = read(path+net+'.'+sta_6C1+'.'+loc+'.'+cha_6C+'.D.'+YYYY+'.'+DOY)
st_6C2_raw = read(path+net+'.'+sta_6C2+'.'+loc+'.'+cha_6C+'.D.'+YYYY+'.'+DOY)

print(st_6C0_raw)
# Out:
# 6 Trace(s) in Stream:
# XX.6C00..DJX | 2023-09-28T14:53:42.775000Z - 2023-09-28T14:54:41.775000Z | 400.0 Hz, 23601 samples
# XX.6C00..DJY | 2023-09-28T14:53:42.775000Z - 2023-09-28T14:54:41.775000Z | 400.0 Hz, 23601 samples
# XX.6C00..DJZ | 2023-09-28T14:53:42.775000Z - 2023-09-28T14:54:41.775000Z | 400.0 Hz, 23601 samples
# XX.6C00..DNX | 2023-09-28T14:53:42.775000Z - 2023-09-28T14:54:41.775000Z | 400.0 Hz, 23601 samples
# XX.6C00..DNY | 2023-09-28T14:53:42.775000Z - 2023-09-28T14:54:41.775000Z | 400.0 Hz, 23601 samples
# XX.6C00..DNZ | 2023-09-28T14:53:42.775000Z - 2023-09-28T14:54:41.775000Z | 400.0 Hz, 23601 samples

# %% [markdown]
# Let's make sure that the PCB data and the IMU50 dara has the same sampling_rate:

# %%
# filter displacement data
do_resample = False
if st_6C0_raw[0].stats.sampling_rate != st_ACC0[0].stats.sampling_rate:
    do_resample = True
st_6C0 = st_6C0_raw.copy()
st_6C1 = st_6C1_raw.copy()
st_6C2 = st_6C2_raw.copy()
for tr in st_6C0:
    mean = np.mean(tr.data[:800])
    tr.data = tr.data-mean
if do_resample:
    st_6C0.filter('lowpass', freq = 100, corners=4, zerophase=True)
    st_6C0.resample(250)

for tr in st_6C1:
    mean = np.mean(tr.data[:800])
    tr.data = tr.data-mean
if do_resample:
    st_6C1.filter('lowpass', freq = 100, corners=4, zerophase=True)
    st_6C1.resample(250)

for tr in st_6C2:
    mean = np.mean(tr.data[:800])
    tr.data = tr.data-mean
if do_resample:
    st_6C2.filter('lowpass', freq = 100, corners=4, zerophase=True)
    st_6C2.resample(250)

# %% [markdown]
# The sampling rate is an important parameter, so let's extract it.

# %%
sps = st_ACC0[0].stats.sampling_rate

# %% [markdown]
# No we can start with the analysis. First we filter the data from the displacement transducers and from the PCB sensors.

# %%
st_DISP0_f = st_DISP0.copy()
st_DISP1_f = st_DISP1.copy()
st_DISP2_f = st_DISP2.copy()
st_DISP0_f.filter('bandpass', freqmin=fmin, freqmax=fmax, corners=4, zerophase=True)
st_DISP1_f.filter('bandpass', freqmin=fmin, freqmax=fmax, corners=4, zerophase=True)
st_DISP2_f.filter('bandpass', freqmin=fmin, freqmax=fmax, corners=4, zerophase=True)

st_ACC0.detrend('linear')
st_ACC1.detrend('linear')
st_ACC2.detrend('linear')

st_ACC0_orig = st_ACC0.copy()
st_ACC1_orig = st_ACC1.copy()
st_ACC2_orig = st_ACC2.copy()

st_ACC0.filter('bandpass', freqmin=fmin, freqmax=fmax, corners=4, zerophase=True)
st_ACC1.filter('bandpass', freqmin=fmin, freqmax=fmax, corners=4, zerophase=True)
st_ACC2.filter('bandpass', freqmin=fmin, freqmax=fmax, corners=4, zerophase=True)
# Out:
# 3 Trace(s) in Stream:
# XX.AC02..DNY | 2023-09-28T14:53:42.775000Z - 2023-09-28T14:54:41.775000Z | 400.0 Hz, 23601 samples
# XX.AC02..DNY | 2023-09-28T14:53:42.775000Z - 2023-09-28T14:54:41.775000Z | 400.0 Hz, 23601 samples
# XX.AC02..DNY | 2023-09-28T14:53:42.775000Z - 2023-09-28T14:54:41.775000Z | 400.0 Hz, 23601 samples

# %% [markdown]
# Next we perform the normal double integration on the PCB data. we subtrach the pre-event offset after each integration step.

# %%
    
# preprocess acceleration data and double integration
st_vel0 = st_ACC0.copy()
for tr in st_vel0:
    mean = np.mean(tr.data[0:400])
    tr.data = tr.data - mean
st_vel0.integrate()
st_dis0 = st_vel0.copy()
for tr in st_dis0:
    mean = np.mean(tr.data[0:400])
    tr.data = tr.data - mean
st_dis0.integrate()


st_vel1 = st_ACC1.copy()
for tr in st_vel1:
    mean = np.mean(tr.data[0:400])
    tr.data = tr.data - mean
st_vel1.integrate()
st_dis1 = st_vel1.copy()
for tr in st_dis1:
    mean = np.mean(tr.data[0:400])
    tr.data = tr.data - mean
st_dis1.integrate()


st_vel2 = st_ACC2.copy()
for tr in st_vel2:
    mean = np.mean(tr.data[0:400])
    tr.data = tr.data - mean
st_vel2.integrate()
st_dis2 = st_vel2.copy()
for tr in st_dis2:
    mean = np.mean(tr.data[0:400])
    tr.data = tr.data - mean
st_dis2.integrate()

st_dis0.filter('bandpass', freqmin=fmin, freqmax=fmax, corners=4, zerophase=True)
st_dis1.filter('bandpass', freqmin=fmin, freqmax=fmax, corners=4, zerophase=True)
st_dis2.filter('bandpass', freqmin=fmin, freqmax=fmax, corners=4, zerophase=True)
# Out:
# 3 Trace(s) in Stream:
# XX.AC02..DNY | 2023-09-28T14:53:42.775000Z - 2023-09-28T14:54:41.775000Z | 400.0 Hz, 23601 samples
# XX.AC02..DNY | 2023-09-28T14:53:42.775000Z - 2023-09-28T14:54:41.775000Z | 400.0 Hz, 23601 samples
# XX.AC02..DNY | 2023-09-28T14:53:42.775000Z - 2023-09-28T14:54:41.775000Z | 400.0 Hz, 23601 samples

# %% [markdown]
# Now we perform the attitude corrected double integration. Filter and baseline correction steps are exactely the same as in the normal double integration.

# %%
data_corr_0 = apply_att_corr(st_6C0, fmin, fmax, sps, one_g)
data_corr_1 = apply_att_corr(st_6C1, fmin, fmax, sps, one_g)
data_corr_2 = apply_att_corr(st_6C2, fmin, fmax, sps, one_g)

(
TAxGl0, TAyGl0, TAzGl0,
TVxGl0, TVyGl0, TVzGl0,
TDxGl0, TDyGl0, TDzGl0,
EAxGl0, EAyGl0, EAzGl0,
) = data_corr_0

(
TAxGl1, TAyGl1, TAzGl1,
TVxGl1, TVyGl1, TVzGl1,
TDxGl1, TDyGl1, TDzGl1,
EAxGl1, EAyGl1, EAzGl1,
) = data_corr_1

(
TAxGl2, TAyGl2, TAzGl2,
TVxGl2, TVyGl2, TVzGl2,
TDxGl2, TDyGl2, TDzGl2,
EAxGl2, EAyGl2, EAzGl2,
) = data_corr_2

# %% [markdown]
# Now we perform the single integration on the raw and unfiltered IMU50 rotation rate data. We also do a baseline correction.

# %%
for tr in st_6C0_raw:
    mean = np.mean(tr.data[:800])
    tr.data = tr.data-mean

for tr in st_6C1_raw:
    mean = np.mean(tr.data[:800])
    tr.data = tr.data-mean
 
for tr in st_6C2_raw:
    mean = np.mean(tr.data[:800])
    tr.data = tr.data-mean
           
st_6C0_raw_int = st_6C0_raw.select(channel='DJX').integrate()
st_6C1_raw_int = st_6C1_raw.select(channel='DJX').integrate()
st_6C2_raw_int = st_6C2_raw.select(channel='DJX').integrate()

# %% [markdown]
# In the next cell we assign more readable names to our variables in order not to get confused, when calculating the IDRs.

# %%
disp_gndfloor_corr = TDyGl0
disp_1stfloor_corr = TDyGl1
disp_2ndfloor_corr = TDyGl2

disp_gndfloor_ref = st_DISP0[0].data * 1e-3
disp_1stfloor_ref = st_DISP1[0].data * 1e-3
disp_2ndfloor_ref = st_DISP2[0].data * 1e-3

disp_gndfloor_refa = st_dis0[0].data# * -1e0
disp_1stfloor_refa = st_dis1[0].data# * -1e0
disp_2ndfloor_refa = st_dis2[0].data# * -1e0

# %% [markdown]
# No we can calculate the IDRs

# %%
id_corr_2nd = 100*(disp_2ndfloor_corr - disp_1stfloor_corr) / 1.78
id_ref_2nd = 100*(disp_2ndfloor_ref - disp_1stfloor_ref) / 1.78
id_refa_2nd = 100*(disp_2ndfloor_refa - disp_1stfloor_refa) / 1.78
id_rot_2nd = 100*st_6C2_raw_int.select(channel='DJX')[0].data

EV['max_id_ref_2nd'] = np.max(abs(id_ref_2nd))
idx_max_id_ref_2nd = np.argmax(abs(id_ref_2nd))

EV['max_id_corr_2nd'] = np.max(abs(id_corr_2nd))
idx_max_id_corr_2nd = np.argmax(abs(id_corr_2nd))

EV['max_id_refa_2nd'] = np.max(abs(id_refa_2nd))
idx_max_id_refa_2nd = np.argmax(abs(id_refa_2nd))

EV['max_id_rot_2nd'] = np.max(abs(id_rot_2nd))
idx_max_id_rot_2nd = np.argmax(abs(id_rot_2nd))

id_corr_1st = 100*(disp_1stfloor_corr - disp_gndfloor_corr) / 2.02
id_ref_1st = 100*(disp_1stfloor_ref - disp_gndfloor_ref) / 2.02
id_refa_1st = 100*(disp_1stfloor_refa - disp_gndfloor_refa) / 2.02
id_rot_1st = 100*st_6C1_raw_int.select(channel='DJX')[0].data

# scale
static_deform_rot_1st = np.mean(id_rot_1st[-600:]) - np.mean(id_rot_1st[:600])
static_deform_rot_2nd = np.mean(id_rot_2nd[-600:]) - np.mean(id_rot_2nd[:600])

static_deform_ref_1st = np.mean(id_ref_1st[-600:]) - np.mean(id_ref_1st[:600])
static_deform_ref_2nd = np.mean(id_ref_2nd[-600:]) - np.mean(id_ref_2nd[:600])

EV['static_def_rot_1st'] = static_deform_rot_1st
EV['static_def_ref_1st'] = static_deform_ref_1st
EV['static_def_rot_2nd'] = static_deform_rot_2nd
EV['static_def_ref_2nd'] = static_deform_ref_2nd

EV['max_id_ref_1st'] = np.max(abs(id_ref_1st))
idx_max_id_ref_1st = np.argmax(abs(id_ref_1st))

EV['max_id_corr_1st'] = np.max(abs(id_corr_1st))
idx_max_id_corr_1st = np.argmax(abs(id_corr_1st))

EV['max_id_refa_1st'] = np.max(abs(id_refa_1st))
idx_max_id_refa_1st = np.argmax(abs(id_refa_1st))

EV['max_id_rot_1st'] = np.max(abs(id_rot_1st))
idx_max_id_rot_1st = np.argmax(abs(id_rot_1st))

diff0c = ((id_ref_1st[:-1] - id_corr_1st))
diff1c = ((id_ref_2nd[:-1] - id_corr_2nd))

diff0nc = ((id_ref_1st[:] - id_refa_1st))
diff1nc = ((id_ref_2nd[:] - id_refa_2nd))

# %% [markdown]
# The rest is plotting.

# %%
#define colors for plots:
c1 = (0,0,0)
c2 = (0.9, 0.6, 0)
c3 = (0.35, 0.7, 0.9)
c4 = (0, 0.6, 0.5)

# %%
# define a time axis
sc = np.arange(0, st_DISP0[0].stats.npts, 1)*st_DISP0[0].stats.delta
sc_6C_raw = np.arange(0, st_6C0_raw[0].stats.npts, 1)*st_6C0_raw[0].stats.delta
fs = sps
nperseg = fs*10
nfft = fs*15

f_psdA0, psdA0 = sp.signal.welch(st_ACC0[0].data, fs, nperseg=nperseg, nfft=nfft)
f_psdA1, psdA1 = sp.signal.welch(st_ACC1[0].data, fs, nperseg=nperseg, nfft=nfft)
f_psdA2, psdA2 = sp.signal.welch(st_ACC2[0].data, fs, nperseg=nperseg, nfft=nfft)

f_psdA0c, psdA0c = sp.signal.welch(TAyGl0, fs, nperseg=nperseg, nfft=nfft)
f_psdA1c, psdA1c = sp.signal.welch(TAyGl1, fs, nperseg=nperseg, nfft=nfft)
f_psdA2c, psdA2c = sp.signal.welch(TAyGl2, fs, nperseg=nperseg, nfft=nfft)

R0_data = st_6C0_raw_int.select(channel='DJX')[0].data
R1_data = st_6C1_raw_int.select(channel='DJX')[0].data
R2_data = st_6C2_raw_int.select(channel='DJX')[0].data

f_psdR0, psdR0 = sp.signal.welch(R0_data, fs, nperseg=nperseg, nfft=nfft)
f_psdR1, psdR1 = sp.signal.welch(R1_data, fs, nperseg=nperseg, nfft=nfft)
f_psdR2, psdR2 = sp.signal.welch(R2_data, fs, nperseg=nperseg, nfft=nfft)

fig_000, ax = plt.subplots(nrows=2, ncols=1, figsize=(3.5, 7.5),
                         gridspec_kw = {'hspace':0.02})

line_Apsd0, = ax[0].loglog(f_psdA0, psdA0, color=c1, linestyle='-', linewidth=1, label='base')
line_Apsd1, = ax[0].loglog(f_psdA1, psdA1, color=c1, linestyle='--', linewidth=1, label='level 1')
line_Apsd2, = ax[0].loglog(f_psdA2, psdA2, color=c1, linestyle=':', linewidth=1, label='level 2')

line_Apsd0c, = ax[0].loglog(f_psdA0c, psdA0c, color=c3, linestyle='-', linewidth=1, label='attitude corr.')
line_Apsd1c, = ax[0].loglog(f_psdA1c, psdA1c, color=c3, linestyle='--', linewidth=1, label='level 1')
line_Apsd2c, = ax[0].loglog(f_psdA2c, psdA2c, color=c3, linestyle=':', linewidth=1, label='level 2')

line_Rpsd0, = ax[1].loglog(f_psdR0, psdR0, color=c1, linestyle='-', linewidth=1, label='base')
line_Rpsd1, = ax[1].loglog(f_psdR1, psdR1, color=c1, linestyle='--', linewidth=1, label='level 1')
line_Rpsd2, = ax[1].loglog(f_psdR2, psdR2, color=c1, linestyle=':', linewidth=1, label='level 2')

ax[0].axvline(0.5, color='r', lw=1.5)
ax[0].axvline(1, color='r', lw=1.5)
ax[0].axvline(2, color='r', lw=1.5)

ax[1].axvline(0.5, color='r', lw=1.5)
ax[1].axvline(1, color='r', lw=1.5)
ax[1].axvline(2, color='r', lw=1.5)

ax[0].set_xlim(0.3, 10)
ax[1].set_xlim(0.3, 10)

ax[0].set_ylim(5e-4, 1e1)
ax[1].set_ylim(2e-12, 1e-6)

ax[1].set_xlabel('frequency [Hz]')
ax[0].set_ylabel('acceleration PSD [m$^2$/s$^4$/Hz]')
ax[1].set_ylabel('rotation PDS [rad$^2$/Hz]')

ax[0].tick_params(axis='both', which='both', direction='in',
                     labelleft=True, labeltop=False, labelright=False, labelbottom=False, labelsize=9)
ax[1].tick_params(axis='both', which='both', direction='in',
                     labelleft=True, labeltop=False, labelright=False, labelbottom=True, labelsize=9)


ax[0].grid(visible=True)
ax[1].grid(visible=True)

ax[0].text(0.3, 1.02 , 'event: '+EV['ename'], weight='bold', transform=ax[0].transAxes)

lines1 = (line_Apsd0, line_Apsd1, line_Apsd2, line_Apsd0c)
ax[0].legend(handles=lines1, loc='upper left', fontsize=9, framealpha=1)

plt.savefig('plots/psds_attcorr_evt'+evid+'_fmin'+str(fmin)[0]+'p'+str(fmin)[2]+'.png', dpi=300, bbox_inches='tight')
plt.show()



fig_00 = plt.figure(constrained_layout=False, figsize=(7, 8.5))
gs0 = fig_00.add_gridspec(nrows=2, ncols=1, hspace=0.16, height_ratios=[3,2])

gs00 = gs0[0].subgridspec(nrows=2, ncols=3, wspace=0.04, hspace=0.08,)
gs10 = gs0[1].subgridspec(nrows=1, ncols=2, wspace=0.04,)

ax = np.empty(shape=(2,3), dtype=object)
ax1 = np.empty(shape=(2,), dtype=object)
for a in range(2):
    for b in range(3):
        ax[a][b] = fig_00.add_subplot(gs00[a, b])
for a in range(2):
    ax1[a] = fig_00.add_subplot(gs10[a])

line_dis0_r, = ax[1][0].plot(sc[:], st_DISP0_f[0].data, color=c1, linestyle='-', linewidth=1, label='reference')
line_dis1_r, = ax[1][1].plot(sc[:], st_DISP1_f[0].data, color=c1, linestyle='-', linewidth=1, label='reference')
line_dis2_r, = ax[1][2].plot(sc[:], st_DISP2_f[0].data, color=c1, linestyle='-', linewidth=1, label='reference')

line_acc0_ra, = ax[0][0].plot(sc[:], 1*st_ACC0[0].data, color=c2, linestyle='-', linewidth=1, label='w/o attitude corr.')
line_acc1_ra, = ax[0][1].plot(sc[:], 1*st_ACC1[0].data, color=c2, linestyle='-', linewidth=1, label='w/o attitude corr.')
line_acc2_ra, = ax[0][2].plot(sc[:], 1*st_ACC2[0].data, color=c2, linestyle='-', linewidth=1, label='w/o attitude corr.')

line_dis0_ra, = ax[1][0].plot(sc[:], disp_gndfloor_refa*1e3, color=c2, linestyle='-', linewidth=1, label='w/o attitude corr.')
line_dis0_ra, = ax[1][1].plot(sc[:], disp_1stfloor_refa*1e3, color=c2, linestyle='-', linewidth=1, label='w/o attitude corr.')
line_dis0_ra, = ax[1][2].plot(sc[:], disp_2ndfloor_refa*1e3, color=c2, linestyle='-', linewidth=1, label='w/o attitude corr.')

line_acc0_c, = ax[0][0].plot(sc[:-1], TAyGl0, color=c3, linestyle='-', linewidth=0.5, label='with attitude corr.')
line_acc1_c, = ax[0][1].plot(sc[:-1], TAyGl1, color=c3, linestyle='-', linewidth=0.5, label='with attitude corr.')
line_acc2_c, = ax[0][2].plot(sc[:-1], TAyGl2, color=c3, linestyle='-', linewidth=0.5, label='with attitude corr.')

line_dis0_c, = ax[1][0].plot(sc[:-1], disp_gndfloor_corr*1e3, color=c3, linestyle='-', linewidth=0.5, label='with attitude corr.')
line_dis1_c, = ax[1][1].plot(sc[:-1], disp_1stfloor_corr*1e3, color=c3, linestyle='-', linewidth=0.5, label='with attitude corr.')
line_dis2_c, = ax[1][2].plot(sc[:-1], disp_2ndfloor_corr*1e3, color=c3, linestyle='-', linewidth=0.5, label='with attitude corr.')



ax[1][0].set_xlabel('time [s]')
ax[1][1].set_xlabel('time [s]')
ax[1][2].set_xlabel('time [s]')
ax[0][0].set_ylabel('acc [m/s$^2$]')
ax[1][0].set_ylabel('disp [mm]')

ax[0][0].tick_params(axis='both', which='major', direction='in',
                     labelleft=True, labeltop=False, labelright=False, labelbottom=False, labelsize=9)
ax[1][0].tick_params(axis='both', which='major', direction='in',
                     labelleft=True, labeltop=False, labelright=False, labelbottom=True, labelsize=9)
ax[0][1].tick_params(axis='both', which='major', direction='in',
                     labelleft=False, labeltop=False, labelright=False, labelbottom=False, labelsize=9)
ax[1][1].tick_params(axis='both', which='major', direction='in',
                     labelleft=False, labeltop=False, labelright=False, labelbottom=True, labelsize=9)
ax[0][2].tick_params(axis='both', which='major', direction='in',
                     labelleft=False, labeltop=False, labelright=False, labelbottom=False, labelsize=9)
ax[1][2].tick_params(axis='both', which='major', direction='in',
                     labelleft=False, labeltop=False, labelright=False, labelbottom=True, labelsize=9)

ax[0][0].grid(visible=True)
ax[1][0].grid(visible=True)
ax[0][1].grid(visible=True)
ax[1][1].grid(visible=True)
ax[0][2].grid(visible=True)
ax[1][2].grid(visible=True)

ax[0][0].set_ylim(-25, 25)
ax[0][1].set_ylim(-25, 25)
ax[0][2].set_ylim(-25, 25)

ax[1][0].set_ylim(-90, 90)
ax[1][1].set_ylim(-90, 90)
ax[1][2].set_ylim(-90, 90)

xlim_min = 7.5
xlim_max = 13


ax[0][0].set_xlim(xlim_min, xlim_max)
ax[0][1].set_xlim(xlim_min, xlim_max)
ax[0][2].set_xlim(xlim_min, xlim_max)
ax[1][0].set_xlim(xlim_min, xlim_max)
ax[1][1].set_xlim(xlim_min, xlim_max)
ax[1][2].set_xlim(xlim_min, xlim_max)


#ax[0][0].text(0.5, 1.06 , EV['ename']+', bandpass filter: '+str(fmin)+'Hz - '+str(fmax)+'Hz', weight='bold', transform=ax[0][0].transAxes)
ax[0][0].text(0.5, 1.04 , 'event: '+ EV['ename'], weight='bold', transform=ax[0][0].transAxes)
ax[1][0].text(0.1, 0.95 , 'base', weight='bold', transform=ax[1][0].transAxes, backgroundcolor='w')
ax[1][1].text(0.1, 0.95 , 'level 1', weight='bold', transform=ax[1][1].transAxes, backgroundcolor='w')
ax[1][2].text(0.1, 0.95 , 'level 2', weight='bold', transform=ax[1][2].transAxes, backgroundcolor='w')       


line_id1_r, = ax1[0].plot(sc[:], id_ref_1st, color=c1, linestyle='-', linewidth=1, label='refernce')
line_id1_ra, = ax1[0].plot(sc[:], id_refa_1st, color=c2, linestyle='-', linewidth=1, label='double integration')
line_id1_c, = ax1[0].plot(sc[:-1], id_corr_1st, color=c3, linestyle='-', linewidth=0.5, label='attitude corr. double int.')
line_id2_r, = ax1[1].plot(sc[:], id_ref_2nd, color=c1, linestyle='-', linewidth=1)
line_id2_ra, = ax1[1].plot(sc[:], id_refa_2nd, color=c2, linestyle='-', linewidth=1)
line_id2_c, = ax1[1].plot(sc[:-1], id_corr_2nd, color=c3, linestyle='-', linewidth=0.5)


lines1 = (line_dis0_r, line_dis0_ra, line_dis0_c)

ax1[0].legend(handles=lines1, loc='upper right', fontsize=9, framealpha=1)

ax1[0].set_xlabel('time [s]')
ax1[1].set_xlabel('time [s]')
ax1[0].set_ylabel('IDR [%]')

ax1[0].tick_params(axis='both', which='major', direction='in',
                     labelleft=True, labeltop=False, labelright=False, labelbottom=True, labelsize=9)
ax1[1].tick_params(axis='both', which='major', direction='in',
                     labelleft=False, labeltop=False, labelright=False, labelbottom=True, labelsize=9)


ax1[0].grid(visible=True)
ax1[1].grid(visible=True)
ax1[0].set_ylim(-2, 2)
ax1[1].set_ylim(-2, 2)
ax1[0].set_xlim(2.6, 19.8)
ax1[1].set_xlim(2.6, 19.8)


ax1[0].text(11, -2.7 , 'level 1', weight='bold', backgroundcolor='w')
ax1[1].text(11, -2.7 , 'level 2', weight='bold', backgroundcolor='w')

plt.savefig('plots/waveforms_attcorr_evt'+evid+'_fmin'+str(fmin)[0]+'p'+str(fmin)[2]+'.png', dpi=300, bbox_inches='tight')
plt.show()
